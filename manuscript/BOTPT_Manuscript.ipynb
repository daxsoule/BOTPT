# %% [markdown]
# # The relationship between post-2015 eruption deformation and seismicity rates since the 2015 eruption at Axial Seamount
# # The relationship between seafloor deformation and seismicity rates at Axial Seamount post-2015 eruption

# %% [markdown]
# ### Abstract
# The Ocean Observatories Initiative Cabled Array (OOI-CA) provides the opportunity to use new approaches to observe geological  processes at Axial Seamount, an active submarine volcano on the Juan de Fuca spreading ridge located ~300 miles off the coast of Oregon. The OOI-CA provides a suite of interdisciplinary real-time datasets from seismic and geodetic networks and a variety of instruments in two hydrothermal fields with which we can examine system-level processes governing the volcano-marine environment. The geophysical networks comprise 4 Pressure/Tilt (BOTPT) instruments that detect the rise, fall, and tilt of the seafloor as it responds to the movement of magma within the crust and 7 seismometers to monitor earthquakes. In order to better understand the patterns of magma storage and delivery beneath the Axial summit caldera and provide constraints for the development of improved predictive models, we are examining short-term variations in the rates of deformation and seismicity and how well they co-vary during the inter-eruption time period. We will also investigate apparent “pauses” in the magma supply rate when the rate of seismicity and deformation have both dropped. On the time-scale of years, seafloor deformation measurements show a relatively steady rate of inflation of the seafloor between eruptions that can be interpreted as reflecting the rate that magma is supplied to the sub-caldera magma reservoir (Nooner and Chadwick 2016). However, on the time-scale of weeks to months, the rate is more variable. Similarly, the rate of earthquakes detected by the OOI seismometer network also varies with time. It was very low immediately after the 2015 eruption, but it has increased markedly over the past year, and based on the observations of prior eruptive cycles, it is expected to increase by several orders of magnitude before the next eruption.

# %% [markdown]
# ### Introduction
#    Axial Seamount rises about ~1 km above the ocean floor and has two major rift zones that extend to the north and south. Its summit is characterized by an 8-km-long caldera and three high-temperature hydrothermal vents (Arnulf, 2014; Wilcock et al, 2018). A magma body sits 1-2 km depth below the summit, stretching beyond the northern and southern extents of the caldera (West et al., 2001; Arnulf et al., 2014, Wilcock et al, 2018). Three eruptions have been observed at Axial Seamount, in 1998, 2011, and 2015, all occuring at a predictable level of inflation. In the 1998 eruption, lava flows occurred on the south rift and total deflation at the summit was ~3.2 m. Total deflation was lower in the 2011 eruption because volume of lava erupted was lower than that of the 1998 eruption. The time interval between the 2011 and 2015 eruptions is shorter than the lapsed time between the 1998 and 2011 eruptions due to increased magma supply, as the 2015 eruption displays the highest rate of inflation (60 cm/year) compared to prior eruptions Nooner and Chadwick, 2016).
#    Crustal deformation generated by volcanism is commonly attributed to inflation of a magma reservoir at depth either by influx of new melt or by volatile exsolution. For this reason, deformation can be used to assess the eruptibility of an active volcano and inform eruption forecasts. On land, surface deformation is commonly measured directly using GPS or InSAR. At Axial Seamount, surface deformation is calculated from measurements of ocean bottom pressure.
#     The first pressure measurements at Axial Seamount began in 1987 and were calculated using autonomous bottom pressure recorders (BPRs), which were deployed and recovered every ~2 years. BPRs are still in use at Axial Seamount, though in 2014, additional instruments cabled real-time to the Ocean Observatories Initiative's Cabled Array (OOI-CA) were deployed on the volcano. The National Science Foundation’s OOI-CA is a network of over 800 instruments that measures the physical, chemical, and biological variables in the ocean and on the seafloor. These new instruments referred to as Bottom Pressure and Tilt instruments (BOTPT) are different from the autonomous BPRs in that they are capable of measuring tilt as well as vertical deformation. They also transmit their data to land in near-real time, eliminating the 2-year waiting period required by the autonomous BPRs. In 2015, the Cabled Array captured an eruption of the volcano in real time, and for this reason, and over its lifetime, the OOI Cabled Array will likely record more eruptions.
#     Seismicity is another useful tool for understanding the dynamics of a volcano. These data are used for imaging magma reservoirs as in Arnulf et al. 2018, for tracking melt migration, dike propagation, and ultimately are critical data to assess the likelihood of a volcanic eruption. There are many styles of earthquakes occurring in volcanically active regions and they provide a wealth of information about the physical processes occuring within and surrounding a reservoir. Commonly, these earthquakes are attributed to crustal rock breaking as magmatic dikes migrate away from the reservoir and toward the surface. For our study, we seek to quantify and model the relationship between seismicity induced by the the breaking of crustal rock and inflation rate.
#
# diking event - horizontal component of deformation
# Earthquakes: magnitude, depth, frequency
# Earthquakes are related to magmatic system at depth.
# Overpressurization inside the magma chamber ruptures the elastic strength, when the deformation threshold is reached.
# How does stress trigger eruption?
# Mogi model does not inform us about stress.
# Understanding why rock breaks helps explain why eruption happens.
# Gas exsolution changes the pressure inside the magma chamber.
# Earthquakes get bigger and closer to the surface leading up to the eruption.
#
# "Microearthquakes that occurred during 2015–2016 were located on portions of an outward-dipping ring fault system that was reactivated in response to the inflation and deflation of the underlying magma chamber" (Levy et al, 2018).

# %% [markdown]
# ### Methods
# We utilized two methods to examine the rates of inflation and seismicity at the Axial. The first method involved downsampling the bottom pressure data to 15 seconds and subtracting the tidal data from it to remove tidal variations. Daily average was then obtained and compared to seismic measurements at the same interval. In the second method, inflation rate was calculated by subtracting the difference between detided depth from the Bottom Pressure Measurements (BPR) with the highest inflation rate and the site with the lowest inflation rate. The later method, even though it does not represent the actual inflation values, gives a better representation of the volcanic inflation signal because it removes tidal residuals and most oceanographic effects that are common to both stations, which are only a few kilometers apart.
# Look at hydrophone data.
# Mogi equation on Jupyter to constrain deformation (change the radius of magma chamber, Young's moudulus, etc)

# %% [markdown]
# ### Results
# Short-term (days to weeks) variability between deformation and seismicity shows a direct relationship.
# The relation between deformation and seismicity rates changes over time during the intereruption period. Following the 2015 eruption, a given inflation rate is associated with minor seismicity. However, further in the inter-eruption cycle, the same inflation rate is now accompanied by a higher rate of seismicity.

# %% [markdown]
# ### Discussion

# %% [markdown]
# ### Conclusions

# %% [markdown]
# ### Citations
# Chadwick, W.W., Jr., Paduan, J.B., Clague, D.A., Dreyer, B.M., Merle, S.G., Bobbitt, A.M., Caress, D.W., Philip, B.T., Kelley, D.S., Nooner, S.L. (2016). Voluminous eruption from a zoned magma body after an increase in supply rate at Axial Seamount. Geophys. Res. Lett., 43, 12,063–12,070. doi:10.1002/ 2016GL071327.
#
# Clague, D.A., B.M. Dreyer, J.B. Paduan, J.F. Martin, W.W. Chadwick Jr., D.W. Caress,
# R.A. Portner, T.P. Guilderson, M.L. McGann,D.A. Butterfield, and others. 2013. Geologic history of the summit of Axial Seamount, Juan de Fuca Ridge. Geochemistry, Geophysics, Geosystems 14:4,403–4,443, https://doi.org/10.1002/ggge.20240.
#
# Levy, S., Bohnenstiehl, D.R., Sprinkle, P., Boettcher, M.S., Wilcock, W.S.D., Tolstoy, M., and Waldhauser, F. (2018). Mechanics of fault reactivation before, during, and after the 2015 eruption of Axial Seamount.  Geology, .
#
# Nooner, S.L., and W.W. Chadwick Jr. 2009. Volcanic inflation measured in the caldera of Axial Seamount: Implications for magma supply and future eruptions. Geochemistry, Geophysics, Geosystems 10, Q02002, https://doi.org/ 10.1029/2008GC002315.
#
# Nooner, S.L., and W.W. Chadwick Jr. 2016. Inflation- predictable behavior and co-eruption deforma- tion at Axial Seamount. Science 354:1,399–1,403, https://doi.org/10.1126/science.aah4666.
#
# Wilcock, W., Dziak, R., Tolstoy, M., Chadwick, W., Nooner, S., Bohnenstiehl, D., . . . Mann, M. (2018). THE RECENT VOLCANIC HISTORY OF AXIAL SEAMOUNT: Geophysical Insights into Past Eruption Dynamics with an Eye Toward Enhanced Observations of Future Eruptions. Oceanography, 31(1), 114-123. R
#
# Wilcock, W.S.D., M. Tolstoy, F. Waldhauser, C. Garcia, Y.J. Tan, D.R. Bohnenstiehl, J. Caplan- Auerbach, R.P. Dziak, A.F. Arnulf, and M.E. Mann. 2016. Seismic constraints on caldera dynam-
# ics from the 2015 Axial Seamount eruption. Science 354:1,395–1,399, https://doi.org/10.1126/ science.aah5563.
#
# Canales, J.P., Detrick, R.S., Toomey, D.R., and Wilcock, W.S.D. (2003). Segment-scale variations in the crustal structure of 150-300kyr old fast spreading oceanic crust (East Pacific Rise, 8°15'N-10°5'N) from wide-angle seismic refraction profiles. Geophysical Journal International 152, 766-794.

# %% [markdown]
# ### Figures
